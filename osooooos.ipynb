# %% [markdown]
# <a href="https://colab.research.google.com/github/saramakin/osoos/blob/main/osooooos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random
from google.colab.patches import cv2_imshow
from collections import ChainMap

class Oso():
  def __init__(self, nombre):
    self.__razas = ['Oso Pardo', 'Oso Malayo', 'Oso Panda', 'Oso Negro Asiatico', 'Oso Polar']
    self.__info_osos = {
        'Oso Pardo': {
            'color': 'Es color Cafe',
            'habitat': 'Los osos pardos se encuentran en partes de América del Norte, Escandinavia a Europa del Este, Siria al Himalaya y los Pirineos, Alpes y montañas de los Cárpatos.',
            'imagen': cv2.imread('/content/drive/MyDrive/imagenes_python/Oso_Pardo.jpg', cv2.IMREAD_COLOR),
            'comida': 'Su comida favorita son los alces y bisontes, aunque en primavera le gusta comer hierbas y juncos',
            'dieta':'Los osos pardos son omnívoros. Los tipos de plantas que más comen son las raíces carnosas, las frutas, las bayas, las hierbas y los forbos. Si los osos pardos están de caza, sus presas pueden ser peces (especialmente salmones), roedores como ardillas de tierra, carroña y animales con pezuñas como alces, alces, caribúes y ciervos.',
            'tamano':'Los osos pardos adultos parados pueden llegar a medir 2.4 metros estando en 2 patas'},
            
        'Oso Malayo': {
            'color': 'Es negro y amarillento',
            'habitat':'Los osos Malayos habitan en bosques tropicales del sureste asiático, concretamente en el centro-oeste de Birmania, Indochina, Malaca, Sumatra y Borneo',
            'imagen': cv2.imread('/content/drive/MyDrive/imagenes_python/Oso_Malayo.jpg', cv2.IMREAD_COLOR),
            'comida':'La comida favorita del oso malayo son las frutas e insectos',
            'dieta':'Los osos malayos Se alimentan de frutas dulces, pequeños roedores, aves, termitas y otros insectos. En los bosques tropicales del sudeste asiático, incluyendo la selva tropical de hoja perenne, el bosque montano y el hábitat de los pantanos. El oso del sol estaba antiguamente muy extendido en los bosques de tierras bajas del sudeste asiático.',
            'tamano':'El oso malayo siendo de los osos mas pequeños puede medir desde 1.2 a 1.5 metros'},

          'Oso Panda': {
              'color': 'Es blanco y negro',
              'imagen': cv2.imread('/content/drive/MyDrive/imagenes_python/Oso_Panda.jpg', cv2.IMREAD_COLOR),
              'habitat': 'Habitan principalmente en bosques de bambú, en lo alto de las montañas del oeste de China',
              'comida': 'Su dieta y por ende su comida favorita es Bambu',
              'dieta': 'Los pandas se alimentan casi exclusivamente de bambú, comiendo de 26 a 84 libras al día',
              'tamano': 'Los osos panda, pueden llegar a medir 1.42 a 1.83 metros estando de pie'},

            'Oso Negro Asiatico': {
              'color': 'Es color negro',
              'imagen': cv2.imread('/content/drive/MyDrive/imagenes_python/Oso_NA.jpg', cv2.IMREAD_COLOR),
              'habitat': 'Se encuentran principalmente en bosques de Asia (de Irán a Japón), preferentemente en áreas montañosas',
              'comida': 'Estos se llenan de grasa antes de hibernar para luego comer piñones y bellotas del año anterior en el periodo de abril-mayo',
              'dieta': 'Los pandas se alimentan casi exclusivamente de bambú, comiendo de 26 a 84 libras al día',
              'tamano':'Los osos negros asiaticos estando de pie miden de 1.5 a 1.7 metros'},

            'Oso Polar': {
                'color': 'Es color  Blanco',
                'imagen': cv2.imread('/content/drive/MyDrive/imagenes_python/Oso_Polar.jpg', cv2.IMREAD_COLOR),
                'habitat':'Viven la gran mayoria de su vida en el hielo marino del océano Ártico',
                'comida': 'La comida favoria del oso Polar son las focas anilladas y barbudas',
                'dieta': 'Los osos polares se alimentan principalmente de focas anilladas y barbudas, pero dependiendo de su ubicación, pueden comer focas de arpa, de capucha y de cinta. Una foca de 121 libras puede proporcionar energía para 8 días, pero el oso necesita comer mucho más para acumular reservas.',
                'tamano': 'Estos siendo los mas grandes de los 5 osos presentados estando de pie miden mas de 3 metros'}
            }
        
    self.raza = random.choice(self.__razas)
    self.info_osos = self.__info_osos[self.raza]
    cv2_imshow(self.info_osos['imagen'])
    # self.habitat = self.__habitat_dado_raza[self.raza]
    # self.comida_fav = self.__comida_dado_raza[self.raza]
    self.come_pescado = 'Si come pescado' if self.raza in ['Oso Pardo', 'Oso Negro Asiatico', 'Oso Polar'] else 'No come pescado'
    self.info_osos = self.__info_osos[self.raza]

# %%
oso1 = Oso('eeeeeeh')
print(oso1.raza)
print(oso1.come_pescado)
print(oso1.info_osos['color'])
print(oso1.info_osos['habitat'])
print(oso1.info_osos['comida'])
print(oso1.info_osos['dieta'])
print(oso1.info_osos['tamano'])
# print(oso1.color_pelaje)
# print(oso1.tamano)
# print(oso1.habitat)
# print(oso1.comida_fav)
# print(oso1.dieta)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F9725ABFBD0>
# Oso Panda
# No come pescado
# Es blanco y negro
# Habitan principalmente en bosques de bambú, en lo alto de las montañas del oeste de China
# Su dieta y por ende su comida favorita es Bambu
# Los pandas se alimentan casi exclusivamente de bambú, comiendo de 26 a 84 libras al día
# Los osos panda, pueden llegar a medir 1.42 a 1.83 metros estando de pie
